# %%
rm(list = ls())
cat("\f")

# %%
library(tseries)
library(rJava)
library(xlsx)
# Out:
# Warning message:
# “package ‘tseries’ was built under R version 3.3.2”Loading required package: xlsxjars

# %%
data.ts = read.xlsx('time_series_data_2017.xlsx',1,rowIndex = 11:826,colIndex = 1:2);

# %%
options(repr.plot.width=8, repr.plot.height=5)
plot(data.ts$observation_date, data.ts$UNRATE, xlab = 'Date', ylab = 'Unemployment', type='l')
# Out:
# plot without title

# %%
unrate = data.ts$UNRATE
pvalue = adf.test(unrate,k=1)$p.value

# %%
# Question 2

acf(unrate)
# Display the autocorrelations
unrateAutocorrs = acf(unrate)$acf
plot(unrate.autocorrs)
# Out:
# Error in plot(unrate.autocorrs): object 'unrate.autocorrs' not found
# Traceback:
#
# 1. plot(unrate.autocorrs)
# Plot with title “Series  unrate”
